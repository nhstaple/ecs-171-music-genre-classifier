# %%
#Author(s): Jose Torres-Vargas
from pandasDB import DataBase

# %%
db = DataBase()

# %%
#returns a list of dictionaries. Each dictionary is a song that was found
results = db.query('food', False)
data = results['track_data']
data
# Out:
# [{'track_id': 2,
#   'song_title': array(['Food'], dtype=object),
#   'artist_name': array(['AWOL'], dtype=object),
#   'date': array(['2008-11-26 01:48:12'], dtype=object),
#   'genre_top': array(['Hip-Hop'], dtype=object),
#   'set': array(['small'], dtype=object),
#   'X': feature         mfcc                                                    \
#   statistics  kurtosis
#   number            01        02        03        04        05        06
#   track_id
#   2           3.856789  1.541901  0.000816  0.330728  0.118731 -0.342687
#
#   feature                                             ... spectral_contrast  \
#   statistics                                          ...              skew
#   number            07        08        09        10  ...                05
#   track_id                                            ...
#   2          -0.259252  0.146735  0.410656 -0.162872  ...           0.43285
#
#   feature                                                               \
# ...

# %%
#get first result(there might be duplicates)
firstSong = data[0]
#features that are then fed into the model
firstSong['X']
# Out:
# feature         mfcc                                                    \
# statistics  kurtosis
# number            01        02        03        04        05        06
# track_id
# 2           3.856789  1.541901  0.000816  0.330728  0.118731 -0.342687
#
# feature                                             ... spectral_contrast  \
# statistics                                          ...              skew
# number            07        08        09        10  ...                05
# track_id                                            ...
# 2          -0.259252  0.146735  0.410656 -0.162872  ...           0.43285
#
# feature                                                               \
# statistics                         std
# number            06      07        01        02        03        04
# track_id
# 2           1.690805 -1.5719  4.541557  4.321756  3.936234  3.144537
#
# feature
# statistics
# number            05        06        07
# track_id
# ...
